# %% [markdown]
# # AI Sommelier RAG: 이미지와 와인 리뷰로 추천하기
#
# 이 노트북은 검색 없는 추천과 RAG 추천을 비교한다. 요리 이미지를 검색 query로 바꾸고, 앞 노트북에 저장한 Wine Magazine 리뷰를 근거로 와인을 추천한다.
#
# ### 전체 흐름
#
# `이미지 URL → 풍미 query → Retriever → list[Document] → context → 와인 추천`
#
# ### Baseline과 RAG의 차이
#
# - Baseline: 모델의 사전학습 지식만 사용한다.
# - RAG: Pinecone에서 찾은 실제 와인 리뷰를 Prompt의 근거로 사용한다.
#
# ### 사용하는 입력과 저장소
#
# - Multimodal message: 텍스트와 이미지 URL을 한 메시지에 담는다.
# - Query embedding: 이미지에서 만든 풍미 문장을 숫자 vector로 바꾼다.
# - Pinecone index: 앞 노트북에서 만든 `winemag-review-data`를 사용한다.
# - 기본 namespace: 별도 namespace를 지정하지 않은 레코드를 검색한다.
#
# RAG의 인덱싱은 앞 노트북에서 완료했다. 여기서는 요청마다 Retrieval과 Generation을 실행한다. 이미지 해석은 Retrieval에 넣을 query를 만드는 전처리 단계이다.

# %% [markdown]
# ## 패키지 준비
#
# 이 실습은 LangChain Runnable로 OpenAI 모델과 Pinecone Retriever를 연결한다.
#
# - `langchain`: Prompt, Parser, Runnable을 제공한다.
# - `langchain-openai`: 이미지 Chat Model과 query embedding을 제공한다.
# - `langchain-pinecone`: Pinecone index를 LangChain Retriever로 연결한다.
# - `pinecone`: Pinecone 서비스에 접속하는 공식 SDK이다.
# - `python-dotenv`: `.env`의 API 설정을 환경 변수로 불러온다.
# - `langchain-community`: 앞 인덱싱 단계의 `CSVLoader`와 같은 실습 환경을 유지한다.

# %%
# %pip install -U langchain langchain-openai langchain-pinecone langchain-community pinecone python-dotenv
# Out:
# Requirement already satisfied: langchain in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (1.3.15)
# Requirement already satisfied: langchain-openai in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (1.4.3)
# Requirement already satisfied: langchain-pinecone in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (0.2.13)
# Requirement already satisfied: langchain-community in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (0.4.2)
# Requirement already satisfied: pinecone in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (7.3.0)
# Collecting pinecone
#   Using cached pinecone-9.1.0-cp310-abi3-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: python-dotenv in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (1.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.5.4 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain) (1.5.4)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (0.10.16)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.4->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (3.8.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (0.25.0)
# Requirement already satisfied: certifi in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.45.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-openai) (2.52.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: tqdm>4 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (4.70.0)
# Requirement already satisfied: regex in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.7.19)
# Requirement already satisfied: numpy!=2.0.2,>=1.26.4 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-pinecone) (2.5.1)
# Requirement already satisfied: simsimd>=5.9.11 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-pinecone) (6.5.16)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from pinecone) (1.8.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.26.5 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from pinecone) (2.7.0)
# Requirement already satisfied: aiohttp>=3.9.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (3.14.3)
# Requirement already satisfied: aiohttp-retry<3.0.0,>=2.9.1 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (3.4.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: greenlet>=1 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: six>=1.5 in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Requirement already satisfied: colorama in C:\Users\mk\miniforge3\envs\llm_env\Lib\site-packages (from tqdm>4->openai<3.0.0,>=2.45.0->langchain-openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## API 설정 불러오기
#
# `.env`의 API 키는 각 SDK의 인증에 사용하며 화면에 출력하지 않는다.
#
# ### 필요한 설정
#
# - `OPENAI_API_KEY`: 이미지 해석, embedding, 추천 생성에 사용한다.
# - `PINECONE_API_KEY`: `winemag-review-data` index를 검색할 때 사용한다.
# - `OPENAI_EMBEDDING_MODEL`: 앞 인덱싱 단계에서 `text-embedding-3-small`로 설정한다.
#
# ### 앞 노트북과 같아야 하는 값
#
# - embedding 모델: `text-embedding-3-small`이다.
# - index 이름: `winemag-review-data`이다.
# - namespace: 별도 값을 지정하지 않은 기본 namespace이다.
#
# Pinecone index는 앞 인덱싱 노트북에서 생성·적재가 끝난 상태여야 한다.

# %%
import os

from dotenv import load_dotenv

load_dotenv()

CHAT_MODEL_NAME = os.getenv('OPENAI_CHAT_MODEL', 'gpt-5.6-luna')

# %% [markdown]
# ## Baseline 1: 요리 이름으로 와인 추천하기
#
# **Baseline**은 개선 방법의 효과를 비교하기 위한 기준 실행이다. 첫 번째 baseline은 외부 문서를 검색하지 않는다.
#
# - 입력: 요리 이름 `도미회`이다.
# - 처리: Prompt와 모델의 사전학습 지식만 사용한다.
# - 출력: 와인 추천 문자열이다.
# - 한계: 추천에 사용한 외부 리뷰와 출처가 없다.
#
# LCEL의 `|`는 Runnable을 왼쪽에서 오른쪽으로 연결한다. 앞 단계의 출력이 다음 단계의 입력이 된다.

# %% [markdown]
# ### Text Prompt → Chat Model → 문자열
#
# 세 Runnable을 `|`로 연결한다.
#
# - `ChatPromptTemplate`: `system` 지시와 `{query}`를 역할별 message로 만든다.
# - `ChatOpenAI`: message를 받아 `AIMessage`를 생성한다.
# - `StrOutputParser`: `AIMessage`에서 답변 텍스트만 꺼내 `str`로 바꾼다.
#
# 입력과 출력은 `{'query': str} → PromptValue → AIMessage → str` 순서로 변한다.

# %%
from langchain_core.prompts import ChatPromptTemplate

from langchain_core.output_parsers import StrOutputParser

from langchain_openai import ChatOpenAI


# 1. Prompt 생성
text_recommendation_prompt = ChatPromptTemplate.from_messages([
    ('system', '''페르소나: 당신은 와인과 음식 페어링에 대한 열정을 지닌 지식 많고 경험 풍부한 소믈리에이다. 다양한 와인 산지, 포도 품종, 테이스팅 노트에 대한 깊은 이해를 갖고 있다. 친근하고 다가가기 쉬운 태도로 초보자부터 전문가까지 모두가 와인을 즐길 수 있도록 돕는다.

역할: 소믈리에로서 각종 요리에 완벽하게 어울리는 와인을 전문가 수준으로 추천한다. 이용자가 새로운 와인을 탐험하도록 안내하며 와인 테이스팅의 섬세함을 이해할 수 있게 지원한다. 적절한 와인을 매치해 식사 경험을 한층 더 풍성하게 만드는 것이 목표이다.

예시:

* 구운 마늘 버터 새우를 위해서는 샤르도네나 알바리뇨를 추천한다. 와인의 산도가 버터의 풍미와 기름진 맛을 깔끔하게 잡아준다.
* 가성비 좋은 와인을 찾는다면 프랑스 남부의 뮈스카데나나 스페인 리베라 델 두에로 지역의 템프라니요를 추천한다. 각각의 풍미 프로필과 어울리는 요리를 함께 설명한다.
* 와인 보관 방법을 묻는다면 적정 온도(12–14℃), 습도(60–70%), 빛 차단과 진동 방지 등의 실용적인 팁을 제공한다.'''),
    ('human', '''
다음 요리에 어울리는 와인을 추천해주세요. (한국말로 답변해주세요.)

요리명: {query}
'''),
])

# 2. baseline_llm 생성
baseline_llm = ChatOpenAI(
    model_name = CHAT_MODEL_NAME,
    temperature=1, # 답변 다양성 허용
    use_responses_api=True,
    reasoning_effort='none' # 추가 추론 허용X
    # (none, low, medium, high)
)

#3. AImMessage-> str으로 변환하는 객체
output_parser = StrOutputParser()

#4. 3개의 Runnable을 연결(chain)
text_baseline_chain = (text_recommendation_prompt | baseline_llm | output_parser)

#5. baseline 결과 확인
print(text_baseline_chain.invoke({'query':'삼겹살'}))
# Out:
# 삼겹살에는 **산도가 있고 탄닌이 너무 거칠지 않은 레드 와인**이 잘 어울립니다. 기름진 맛을 산도가 씻어주고, 구운 고기의 풍미와 와인의 과실 향이 조화를 이루기 때문입니다.
#
# ### 추천 와인
#
# 1. **스페인 리오하 크리안사 — 템프라니요**
#    - 체리, 자두, 바닐라와 은은한 오크 향
#    - 삼겹살의 구운 풍미와 잘 맞고, 탄닌이 기름기를 정리해줍니다.
#    - 소금이나 쌈장에 찍어 먹는 삼겹살에 특히 추천합니다.
#
# 2. **호주 쉬라즈**
#    - 블랙베리, 후추, 초콜릿 같은 풍미
#    - 불향과 후추 향이 강한 구이와 훌륭하게 어울립니다.
#    - 다만 너무 무겁고 알코올이 높은 제품보다는 중간 바디를 고르세요.
#
# 3. **프랑스 보졸레 — 가메**
#    - 산뜻한 산도와 가벼운 바디, 붉은 과실 풍미
#    - 삼겹살의 느끼함을 깔끔하게 잡아주며, 차갑게 마셔도 좋습니다.
#    - 파채나 마늘, 쌈 채소를 곁들인 삼겹살에 잘 맞습니다.
#
# 4. **독일 리슬링 카비네트 또는 드라이 리슬링**
#    - 상큼한 산도와 레몬·사과 향
#    - 삼겹살의 기름기를 가장 산뜻하게 정리해주는 선택입니다.
#    - 매콤한 쌈장, 김치와 함께라면 약간의 잔당이 있는 리슬링도 좋습니다.
#
# 5. **카바 또는 브뤼 스파클링 와인**
#    - 풍부한 기포와 높은 산도가 입안을 깔끔하게 만들어줍니다.
#    - 삼겹살을 많이 먹을 때 특히 훌륭하며, 김치와 마늘까지 두루 잘 어울립니다.
#
# ### 가장 무난한 한 병
#
# **리오하 크리안사 템프라니요**를 추천합니다. 구운 고기, 쌈장, 마늘, 파채와 모두 무난하게 조화를 이루며 한국식 삼겹살의 풍미를 잘 살려줍니다.
#
# 레드 와인은 **약 15–17℃**, 리슬링과 스파클링 와인은 **7–10℃** 정도로 차게 준비하세요.

# %% [markdown]
# ## Baseline 2: 요리 이미지로 와인 추천하기
#
# **Multimodal message**는 한 메시지에 텍스트와 이미지처럼 서로 다른 입력 형식을 함께 담는다.
#
# - `text` block: 모델이 수행할 요청을 전달한다.
# - `image_url` block: 모델이 읽을 공개 이미지 주소를 전달한다.
# - 출력: 이미지에서 추정한 요리와 와인 추천 문자열이다.
#
# 이미지 URL은 모델 서버가 접근할 수 있어야 한다. 이 단계도 Wine Magazine 리뷰는 검색하지 않는다.

# %%
from langchain_core.prompts import HumanMessagePromptTemplate
#1. Prompt 생성 - HumanMessagePromptTemplate을 이용해서 MultiModal 입력 만들기
image_recommendation_prompt = ChatPromptTemplate.from_messages([
    ('system', '''페르소나: 당신은 와인과 음식 페어링에 대한 열정을 지닌 지식 많고 경험 풍부한 소믈리에이다. 다양한 와인 산지, 포도 품종, 테이스팅 노트에 대한 깊은 이해를 갖고 있다. 친근하고 다가가기 쉬운 태도로 초보자부터 전문가까지 모두가 와인을 즐길 수 있도록 돕는다.

역할: 소믈리에로서 각종 요리에 완벽하게 어울리는 와인을 전문가 수준으로 추천한다. 이용자가 새로운 와인을 탐험하도록 안내하며 와인 테이스팅의 섬세함을 이해할 수 있게 지원한다. 적절한 와인을 매치해 식사 경험을 한층 더 풍성하게 만드는 것이 목표이다.

예시:

* 구운 마늘 버터 새우를 위해서는 샤르도네나 알바리뇨를 추천한다. 와인의 산도가 버터의 풍미와 기름진 맛을 깔끔하게 잡아준다.
* 가성비 좋은 와인을 찾는다면 프랑스 남부의 뮈스카데나나 스페인 리베라 델 두에로 지역의 템프라니요를 추천한다. 각각의 풍미 프로필과 어울리는 요리를 함께 설명한다.
* 와인 보관 방법을 묻는다면 적정 온도(12–14℃), 습도(60–70%), 빛 차단과 진동 방지 등의 실용적인 팁을 제공한다.'''),
    HumanMessagePromptTemplate.from_template([
        {'text': '다음 요리에 어울리는 와인을 추천해주세요. (한국말로 답변해주세요.)'},
        {'image_url': '{image_url}'},
    ]),
])


# 2. chain 구성
image_baseline_chain = (image_recommendation_prompt | baseline_llm | output_parser)

# 3. chain.invoke() # 이때, '{image_url}' 자리에 들어갈 이미지 주소 작성
image_url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRfHLXz1GXCVnbwg-bRtHnZthTMg7mW0jX0nlRa0w_ynQ&s=10'

print(image_baseline_chain.invoke({'image_url':image_url}))
# Out:
# 사진 속 음식은 **돼지 곱창 또는 막창 구이**처럼 보입니다. 불향과 고소한 지방, 쫄깃한 식감이 중심이라 **산도와 탄닌이 적당한 와인**이 잘 어울립니다.
#
# ### 가장 추천: 드라이한 리슬링
# - 독일 모젤 또는 호주산 **드라이 리슬링**
# - 상큼한 산도가 기름기를 말끔히 씻어주고, 레몬·사과 향이 곱창의 진한 풍미를 가볍게 정리합니다.
# - 소금장이나 간장 양념, 부추무침과도 특히 잘 맞습니다.
#
# ### 레드 와인을 원한다면: 보졸레 또는 가벼운 피노 누아
# - **보졸레 빌라주(가메)**: 붉은 과실 풍미와 낮은 탄닌, 산뜻한 질감이 구이의 불향을 살립니다.
# - **피노 누아**: 지나치게 무겁지 않으면서 흙내음과 붉은 과실 향이 내장류의 풍미와 조화를 이룹니다.
# - 레드는 살짝 차갑게, 약 **14–16℃**로 마시면 더욱 좋습니다.
#
# ### 매콤한 양념이라면: 약간의 단맛이 있는 와인
# 양념이 맵고 달다면 **약간 달콤한 독일 리슬링 카비넷**이나 **모스카토 다스티**도 좋습니다. 은은한 단맛이 매운맛을 완화하고 탄산감이 입안을 상쾌하게 해줍니다.
#
# ### 스파클링을 좋아한다면
# **브뤼 샴페인, 까바, 프로세코 브뤼**를 추천합니다. 기포와 산도가 지방감을 깔끔하게 정리해 구이를 계속 맛있게 먹게 해줍니다.
#
# 개인적으로는 **드라이 리슬링 1순위**, 레드 중에서는 **보졸레 빌라주**를 가장 추천드립니다. 곁들이는 소스가 소금장인지 매운 양념인지에 따라 선택하면 더 정확합니다.

# %% [markdown]
# ## Baseline 3: 와인 이미지로 요리 추천하기
#
# 세 번째 baseline은 입력과 출력의 방향을 바꾼다.
#
# - 입력: 와인 라벨 이미지 URL이다.
# - 처리: 라벨과 와인 특징을 multimodal 모델이 해석한다.
# - 출력: 어울리는 요리 추천 문자열이다.
#
# 같은 Prompt → Model → Parser 구조에서도 system 역할과 human 질문을 바꾸면 Chain의 목적이 달라진다.

# %%
wine_image_prompt = ChatPromptTemplate.from_messages([
    ('system', '''페르소나(Persona): 당신은 와인과 음식의 조화를 깊이 이해하는 경험 많은 소믈리에이다. 다양한 와인 산지, 포도 품종, 테이스팅 노트에 대해 해박하며, 누구에게나 친근하고 쉽게 설명하는 능력을 가지고 있다.

역할(Role): 소믈리에로서, 당신의 역할은 특정 와인에 가장 잘 어울리는 요리를 전문적으로 추천하는 것이다. 와인의 향, 맛, 산도, 바디감 등을 분석해 최적의 음식 조합을 제안한다. 당신의 목표는 손님이 가진 와인을 더욱 특별하게 즐길 수 있도록, 완벽한 음식 페어링을 안내하는 것이다.

예시(Examples):

- 누군가가 ‘리슬링(Riesling)’ 와인을 가지고 있다고 하면, 와인의 상큼한 산도와 과일향에 어울리는 매콤한 아시아 요리나 스파이시 치킨을 추천하고 그 이유를 설명한다.
- ‘까베르네 소비뇽(Cabernet Sauvignon)’ 와인에 맞는 음식을 물어보면, 풍부한 탄닌과 바디감을 살려줄 스테이크나 구운 양고기와의 페어링을 안내한다.
- ‘스파클링 와인’에 잘 어울리는 간단한 핑거푸드나 해산물 요리 등을 추천하며, 와인의 청량감을 살리는 방법을 알려준다.
- 특정 와인을 활용한 요리 레시피를 제안하거나, 와인과 함께 먹으면 맛의 밸런스가 좋아지는 음식 스타일을 설명한다.'''),
    HumanMessagePromptTemplate.from_template([
        {'text': '다음 와인에 어울리는 요리를 추천해주세요. (한국말로 답변해주세요.)'},
        {'image_url': '{image_url}'},
    ]),
])
wine_to_food_chain = (wine_image_prompt | baseline_llm | output_parser)
wine_image_url = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRcdTfZdyhemE--AOl5jlh2odJyfhseYxG2xWOpWAEO-w&s=10"

print(wine_to_food_chain.invoke({'image_url':wine_image_url}))
# Out:
# 사진 속 와인은 정확한 라벨 판독이 어렵지만, **청포도 계열의 산뜻하고 달콤한 화이트 와인**으로 보입니다. 향긋한 과실 향과 가벼운 바디감, 비교적 부드러운 산도를 가정하면 다음 요리가 잘 어울립니다.
#
# ### 가장 추천하는 요리
# **매콤달콤한 닭강정 또는 양념치킨**
#
# - 와인의 은은한 단맛이 매운맛과 짭짤한 양념을 부드럽게 완화합니다.
# - 청포도와 과일 향이 치킨의 달콤한 소스와 자연스럽게 연결됩니다.
# - 차갑게 마시면 튀김의 느끼함도 깔끔하게 씻어줍니다.
#
# ### 함께 잘 어울리는 메뉴
# 1. **새우튀김·오징어튀김**
#    - 와인의 산미와 청량감이 튀김의 기름기를 정리해 줍니다.
#    - 레몬을 곁들이면 더욱 산뜻합니다.
#
# 2. **매콤한 태국식·베트남식 요리**
#    - 팟타이, 새우 칠리소스, 분짜, 매콤한 쌀국수 등이 좋습니다.
#    - 와인의 과일 풍미가 고추와 향신료의 자극을 부드럽게 받쳐줍니다.
#
# 3. **과일 치즈 플래터**
#    - 브리 치즈, 크림치즈, 고다 치즈에 청포도·사과·배를 곁들여 보세요.
#    - 와인의 달콤한 과실 향과 부드러운 치즈가 조화롭습니다.
#
# 4. **돼지고기 보쌈**
#    - 담백한 돼지고기와 와인의 과일 향이 잘 맞고, 새우젓이나 매콤한 무김치와도 좋은 균형을 이룹니다.
#
# ### 서빙 팁
# **7~9℃ 정도로 충분히 차갑게** 해서 드시면 과일 향과 상쾌함이 살아납니다. 너무 맵거나 매우 짠 음식보다는 **매콤달콤하고 튀김 또는 해산물이 들어간 요리**가 가장 안정적인 선택입니다.

# %% [markdown]
# ## Wine Magazine 기반 2-step RAG
#
# RAG 본체는 Retrieval과 Generation 두 단계로 구성된다. 이미지 해석은 검색용 query를 만드는 전처리이다.
#
# ### 처리 순서
#
# 1. 이미지 해석: 이미지 URL을 풍미 query 문자열로 바꾼다.
# 2. Retrieval: query와 가까운 리뷰를 `list[Document]`로 가져온다.
# 3. Context 구성: 검색된 `Document.page_content`를 문자열 하나로 묶는다.
# 4. Generation: 풍미와 context를 사용해 와인을 추천한다.
#
# `이미지 URL → 풍미 str → list[Document] → context str → 추천 str`

# %% [markdown]
# ### LCEL에서 사용할 Runnable
#
# `Runnable`은 입력을 받아 한 작업을 수행하고 출력을 반환하는 공통 실행 단위이다. `|`로 여러 Runnable을 연결하면 `RunnableSequence`가 만들어진다.
#
# - `RunnableLambda`: 일반 Python 함수를 LCEL 단계로 사용한다.
# - `RunnableParallel`: 같은 입력을 여러 분기에 전달하고 결과를 dict로 묶는다.
# - `RunnablePassthrough`: 입력값을 바꾸지 않고 그대로 반환한다.
#
# Retrieval 단계는 같은 풍미 문자열을 두 곳에서 사용한다.
#
# - 보존 분기: `dish_flavor`에 원래 문자열을 남긴다.
# - 검색 분기: Retriever가 `retrieved_documents`를 만든다.
# - 병합 결과: `{'dish_flavor': str, 'retrieved_documents': list[Document]}`이다.

# %% [markdown]
# ### 이미지 URL을 검색 query로 바꾸기
#
# Pinecone에는 텍스트 와인 리뷰가 저장되어 있다. 따라서 요리 이미지를 바로 비교하지 않고 텍스트 풍미로 변환한다.
#
# - 입력: `{'image_urls': list[str]}`이다.
# - 변환: 각 URL을 multimodal image block으로 만든다.
# - 출력: 검색에 사용할 영어 한 문장이다.
# - 다음 사용처: Pinecone Retriever의 query로 전달한다.
#
# `describe_dish_flavor()`는 결과 문자열을 직접 반환하지 않는다. 이미지 Prompt → Model → Parser를 연결한 Runnable을 반환한다.

# %%
def describe_dish_flavor(query:dict):

    # 1. 음식 ㅣ이미지-> 영어 한 문장으로 변환 요청 Prompt 생성
    dish_flavor_prompt = ChatPromptTemplate.from_messages([
            ('system', '''페르소나: 당신은 조리 기법, 풍미 특성과 식재료 조합을 깊이 이해하는 뛰어난 음식 전문가이다. 다양한 요리를 탐구하는 데 열정이 있으며 음식의 감각적 경험을 구체적으로 표현할 수 있다. 실무 경험과 이론 지식을 모두 갖추고 있어 신뢰할 수 있는 분석을 제공한다.

    역할: 음식 전문가로서 다양한 요리의 맛, 식감과 향을 분석한다. 식재료와 조리 방법을 구체적으로 평가하고, 균형 있고 조화로운 요리를 만드는 원리를 설명한다. 또한 요리 기술을 향상하고 미식의 가치를 이해할 수 있도록 돕는다.

    예시:

    요리의 풍미 특성을 분석할 때는 산미, 단맛, 쓴맛과 감칠맛의 균형을 설명하고 이 요소들이 어떻게 어우러져 복합적인 맛을 만드는지 분석한다.
    특정 식재료의 풍미를 살리는 방법을 묻는다면 양파를 캐러멜화해 깊은 맛을 내거나 고기의 본연의 맛을 살리도록 적절히 간하는 방법처럼 실용적인 조언을 제공한다.
    음식 조합을 설명할 때는 해산물에 감귤류를 곁들여 산뜻함을 더하거나 허브로 전체 풍미를 끌어올리는 사례처럼 서로 보완하는 식재료와 풍미를 제안하고 그 이유를 설명한다.'''),
            ('human', '''
    이미지를 바탕으로 요리를 분석한다. 와인 리뷰 검색 query로 사용할 수 있도록 핵심 재료, 조리법과 풍미를 영어 한 문장으로 간결하게 출력한다.
    '''),
        ])

    # 2. image_url의 각 문자열을 multimodal image content block으로 변경
    image_contents = [
        {'image_url':image_url}
        for image_url in query.get('image_urls',[])
    ]

    # 3. HumanMessage로 변환하여 Prompt로 추가
    dish_flavor_prompt += HumanMessagePromptTemplate.from_template(image_contents)

    # 4. 이미지를 영어 한 문장으로 변환할 llm 준비
    image_analysis_llm = ChatOpenAI(
        model=CHAT_MODEL_NAME,
        use_responses_api=True,
        temperature=0,
        reasoning_effort='none'
    )

    #5. chain 구성 후 반환
    return dish_flavor_prompt | image_analysis_llm | StrOutputParser()

# %% [markdown]
# ### 이미지 해석 Runnable 실행하기
#
# `RunnableLambda`는 일반 Python 함수를 `invoke()`로 실행할 수 있게 감싼다.
#
# 이 예제에는 한 단계가 더 있다.
#
# 1. `RunnableLambda`가 `describe_dish_flavor(payload)`를 호출한다.
# 2. 함수가 Prompt → Model → Parser Runnable을 반환한다.
# 3. LangChain이 반환된 Runnable에도 같은 `payload`를 전달해 이어서 실행한다.
# 4. 최종 결과로 풍미 문자열을 반환한다.
#
# 출력은 음식·조리법·풍미가 포함된 검색용 영어 한 문장이어야 한다.

# %%
from langchain_core.runnables import RunnableLambda

# 1. 일반 함수 describe_dish_flavor를 LCEL에서 실행할 수 있도록 RunnableLambda로 감싸기
describe_dish_flavor_chain = RunnableLambda(describe_dish_flavor)

# 2. 이미지 주소를 전달하여 결과 확인
dish_flavor = describe_dish_flavor_chain.invoke({
    'image_urls': ['https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1F_JeUtvIFjAAqDABoVnlSEdRjyfx2kDToEAQAJh8LA&s=10']
})

print(dish_flavor)
# Out:
# Pan-fried minced beef patties seasoned with herbs and garlic, offering savory umami, browned crust, juicy tenderness, and aromatic richness.

# %% [markdown]
# ### Pinecone index를 Retriever로 연결하기
#
# 앞 노트북은 와인 리뷰를 `text-embedding-3-small`로 변환해 `winemag-review-data` index의 기본 namespace에 저장했다.
#
# ### 검색 설정
#
# - embedding 모델: 문서 인덱싱과 같은 `text-embedding-3-small`이다.
# - index: `winemag-review-data`이다.
# - namespace: 별도 값을 지정하지 않은 기본 namespace이다.
# - 검색 방식: 의미 유사도 검색이다.
# - `k=5`: 상위 리뷰를 최대 다섯 개 반환한다.
#
# `as_retriever()`는 Vector Store를 `query str → list[Document]` 구조의 검색 인터페이스로 바꾼다.

# %%
from langchain_openai import OpenAIEmbeddings

from langchain_pinecone import PineconeVectorStore

#1. 임베딩 객체 준비
embeddings = OpenAIEmbeddings(model = os.environ['OPENAI_EMBEDDING_MODEL'])

# 2. Pinecone Index와 임베딩 객체를 Vector Store로 묶기
wine_vector_store = PineconeVectorStore(
    index_name='winemag-review-data',
    embedding=embeddings,
)

#3. Vector Store를 query:str -> list[Document]구조로 반환할 Retriever로 변경하기
wine_retriever = wine_vector_store.as_retriever(
    search_type="similarity",
    search_kwargs={'k':5}
)

# %% [markdown]
# ### 대표 query로 검색 결과 확인하기
#
# 이미지 해석 단계와 같은 형식의 영어 풍미 문장을 Retriever에 전달한다.
#
# - 입력: 음식의 재료·조리법·풍미를 설명한 문자열이다.
# - 출력: 유사도 순서의 `list[Document]`이다.
# - 확인할 값: 각 문서의 `page_content`와 `metadata`이다.
#
# 검색 결과가 존재한다고 항상 관련성이 높은 것은 아니다. 생성 전에 음식 풍미와 실제 와인 리뷰가 연결되는지 읽어 본다.

# %%
sample_dish_flavor = (
    'A succulent roast beef garnished with fresh rosemary and accompanied '
    'by vibrant cherry tomatoes and roasted vegetables.'
)

# query -> Retriever -> list[Document]
print('검색 시작')
retrieved_documents = wine_retriever.invoke(sample_dish_flavor)
print(f'검색 완료: {len(retrieved_documents)}개 문서')

if not retrieved_documents:
    print('검색 결과가 없습니다. Pinecone index의 vector 수와 namespace를 확인하세요.')
else:
    for rank, document in enumerate(retrieved_documents, start=1):
        print(f'[{rank}] metadata:', document.metadata)
        print(document.page_content)
        print()
# Out:
# 검색 시작
# 검색 완료: 5개 문서
# [1] metadata: {'row': 19.0, 'source': './winemag-data-130k-v2.csv'}
# : 19
# country: US
# description: Red fruit aromas pervade on the nose, with cigar box and menthol notes riding in the back. The palate is slightly restrained on entry, but opens up to riper notes of cherry and plum specked with crushed pepper. This blend of Merlot, Cabernet Sauvignon and Cabernet Franc is approachable now and ready to be enjoyed.
# designation:
# points: 87
# price: 32.0
# province: Virginia
# region_1: Virginia
# region_2:
# taster_name: Alexander Peartree
# taster_twitter_handle:
# title: Quiévremont 2012 Meritage (Virginia)
# variety: Meritage
# winery: Quiévremont
#
# [2] metadata: {'row': 78.0, 'source': './winemag-data-130k-v2.csv'}
# : 78
# country: US
# description: Some rosés are made simply by bleeding the juice from the fermenter, to concentrate the remaining wine. Whether or not that is the case here, the wine has the simple pleasant lightly candied strawberry flavors one might expect from such a technique. It's fruity and undemanding. Drink up.
# designation: Rosé of
# points: 86
# price: 25.0
# province: Oregon
# region_1: Eola-Amity Hills
# region_2: Willamette Valley
# taster_name: Paul Gregutt
# taster_twitter_handle: @paulgwine
# title: Z'IVO 2015 Rosé of Pinot Noir (Eola-Amity Hills)
# variety: Pinot Noir
# winery: Z'IVO
#
# [3] metadata: {'row': 5.0, 'source': './winemag-data-130k-v2.csv'}
# : 5
# country: Spain
# description: Blackberry and raspberry aromas show a typical Navarran whiff of green herbs and, in this case, horseradish. In the mouth, this is fairly full bodied, with tomatoey acidity. Spicy, herbal flavors complement dark plum fruit, while the finish is fresh but grabby.
# designation: Ars In Vitro
# points: 87
# price: 15.0
# province: Northern Spain
# region_1: Navarra
# region_2:
# taster_name: Michael Schachner
# taster_twitter_handle: @wineschach
# title: Tandem 2011 Ars In Vitro Tempranillo-Merlot (Navarra)
# variety: Tempranillo-Merlot
# winery: Tandem
#
# [4] metadata: {'row': 16.0, 'source': './winemag-data-130k-v2.csv'}
# : 16
# country: Argentina
# description: Baked plum, molasses, balsamic vinegar and cheesy oak aromas feed into a palate that's braced by a bolt of acidity. A compact set of saucy red-berry and plum flavors features tobacco and peppery accents, while the finish is mildly green in flavor, with respectable weight and balance.
# designation: Felix
# points: 87
# price: 30.0
# province: Other
# region_1: Cafayate
# region_2:
# taster_name: Michael Schachner
# taster_twitter_handle: @wineschach
# title: Felix Lavaque 2010 Felix Malbec (Cafayate)
# variety: Malbec
# winery: Felix Lavaque
#
# [5] metadata: {'row': 20.0, 'source': './winemag-data-130k-v2.csv'}
# : 20
# country: US
# description: Ripe aromas of dark berries mingle with ample notes of black pepper, toasted vanilla and dusty tobacco. The palate is oak-driven in nature, but notes of tart red currant shine through, offering a bit of levity.
# designation: Vin de Maison
# points: 87
# price: 23.0
# province: Virginia
# region_1: Virginia
# region_2:
# taster_name: Alexander Peartree
# taster_twitter_handle:
# title: Quiévremont 2012 Vin de Maison Red (Virginia)
# variety: Red Blend
# winery: Quiévremont

# %% [markdown]
# ### 검색 결과를 Generation 입력으로 바꾸기
#
# Generation Prompt에는 원래 풍미와 검색 리뷰가 모두 필요하다.
#
# ### 두 분기의 역할
#
# - `dish_flavor`: `RunnablePassthrough`가 입력 문자열을 그대로 보존한다.
# - `retrieved_documents`: Retriever가 `list[Document]`를 반환한다.
#
# ### 결과 변환
#
# 1. `RunnableParallel`이 두 결과를 dict로 묶는다.
# 2. `format_documents()`가 각 `page_content`를 구분선으로 연결한다.
# 3. `build_retrieval_context()`가 Prompt 변수 이름에 맞춘 dict를 반환한다.
#
# 최종 구조는 `{'dish_flavor': str, 'wine_reviews': str}`이다.

# %%
from langchain_core.documents import Document
from langchain_core.runnables import RunnableParallel, RunnablePassthrough

# 음식 이미지 -> 영어 한 문장 변환한 것 == 풍미 문자열

# 풍미 문자열을 보존하면서 검색하고,
# 생성 프롬프트용 context dict로 변환

# Retriever 검색 결과(list[Document])를
# page_content만 따로 모아둔 하나의 문자열 반환
def format_documents(documents: list[Document]) -> str:
    return '\n\n--- review ---\n\n'.join(
        document.page_content for document in documents
    )

def build_retrieval_context(payload: dict) -> dict:
    return {
        'dish_flavor': payload['dish_flavor'],
        'wine_reviews': format_documents(payload['retrieved_documents']),
    }

# 병렬처리

# 1. 하나의 풍미 문자열을 두 분기에 전달하고 결과를 dict 반환
retrieve_with_query = RunnableParallel(
    dish_flavor=RunnablePassthrough(), # 풍미 문자열(원문)
    retrieved_documents=wine_retriever, # list[Document](검색 결과)
)

# 2. build_retrieval_context를 RunnableLambda로 감싸기
wine_review_retrieval_chain = (
    retrieve_with_query
    | RunnableLambda(build_retrieval_context)
)

# %% [markdown]
# ### Retrieval Runnable의 출력 확인하기
#
# Generation에 연결하기 전에 반환 dict의 구조를 확인한다.
#
# - `dish_flavor`: 처음 입력한 풍미 query 문자열이다.
# - `wine_reviews`: 검색된 리뷰 본문을 합친 context 문자열이다.
#
# 두 key 이름은 다음 `ChatPromptTemplate`의 `{dish_flavor}`, `{wine_reviews}`와 정확히 같아야 한다.

# %%
# Generation Prompt에 전달될 입력 구조 확인
retrieval_payload = wine_review_retrieval_chain.invoke(
    sample_dish_flavor
)

print(list(retrieval_payload))
# Out:
# ['dish_flavor', 'wine_reviews']

# %% [markdown]
# ### 검색 근거로 추천 Runnable 만들기
#
# Generation은 Retrieval이 만든 dict를 Prompt에 채워 최종 추천을 생성한다.
#
# - 입력: `{'dish_flavor': str, 'wine_reviews': str}`이다.
# - Prompt: 요리 풍미와 검색 리뷰를 각각 지정된 위치에 넣는다.
# - Model: 리뷰를 읽고 한국어 추천을 생성한다.
# - Parser: `AIMessage`를 추천 문자열로 바꾼다.
#
# `recommend_wines()`도 결과 문자열이 아니라 Prompt → Model → Parser Runnable을 반환한다. 뒤의 `RunnableLambda`가 반환된 Runnable을 같은 입력 dict로 이어서 실행한다.
#
# 프롬프트 지시만으로 사실 일치가 완전히 보장되지는 않는다. 추천 이름과 이유가 실제 `wine_reviews`에 있는지 별도로 확인한다.

# %%
recommend_wines_prompt = ChatPromptTemplate.from_messages([
        ('system', '''페르소나: 당신은 와인과 음식 페어링에 열정을 지닌 지식 많고 경험 풍부한 소믈리에이다. 다양한 와인 산지, 포도 품종과 테이스팅 노트를 폭넓게 이해한다. 친근하고 다가가기 쉬운 태도로 초보자와 애호가 모두가 와인을 편하게 접할 수 있도록 돕는다.

역할: 소믈리에로서 다양한 요리에 잘 어울리는 와인을 전문적으로 추천한다. 이용자가 새로운 와인을 탐색하도록 안내하고 와인 테이스팅의 섬세한 차이를 이해하도록 돕는다. 적절한 와인과 요리를 연결해 식사 경험을 향상하는 것이 목표이다.

예시:

구운 마늘 버터 새우에 어울리는 와인을 묻는다면 Chardonnay 또는 Albariño를 제안하고, 와인의 산미가 요리의 풍부한 맛과 기름진 느낌을 어떻게 균형 있게 잡아 주는지 설명한다.
가격이 합리적이면서 품질 좋은 와인을 묻는다면 여러 산지의 구체적인 선택지를 추천하고 각 와인의 풍미 특성과 어울리는 음식을 설명한다.
와인 보관법을 설명할 때는 와인의 품질을 유지할 수 있는 온도, 습도와 적절한 보관 조건을 실용적으로 안내한다.'''),
        ('human', '''
와인 페어링 추천해주세요.
아래의 요리설명과 와인리뷰만을 참고하여 한글로 답변해주세요.
아래의 요리설명과 와인리뷰외의 내용을 추가하지 말아주세요.

요리설명:
{dish_flavor}

와인리뷰:
{wine_reviews}

추천 와인과 이유:
'''),
    ])

# %% [markdown]
# ### 전체 이미지 RAG Chain 연결하기
#
# 세 Runnable을 `|`로 연결한다. 각 단계의 출력 자료형이 다음 단계의 입력 자료형과 이어져야 한다.
#
# 1. `describe_dish_flavor_chain`: `{'image_urls': list[str]}` → 풍미 `str`이다.
# 2. `wine_review_retrieval_chain`: 풍미 `str` → `{dish_flavor, wine_reviews}` dict이다.
# 3. `recommend_wines_chain`: 검색 context dict → 추천 `str`이다.
#
# 이미지 해석은 query 전처리이고, Retrieval과 Generation이 2-step RAG 본체이다. 최종 Chain은 추천 문자열만 반환하므로 검색 근거는 앞의 Retrieval 출력 확인 단계에서 별도로 검토한다.

# %%
# 검색된 리뷰를 근거로 최종 추천문을 생성하는 체인
recommend_wines_chain = (
    recommend_wines_prompt
    | baseline_llm
    | output_parser
)

# 이미지 분석 -> 리뷰 검색 -> 추천 생성을 하나의 RAG 체인으로 연결
ai_sommelier_rag_chain = (
    describe_dish_flavor_chain
    | wine_review_retrieval_chain
    | recommend_wines_chain
)

rag_result = ai_sommelier_rag_chain.invoke({
    'image_urls': [
        'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1F_JeUtvIFjAAqDABoVnlSEdRjyfx2kDToEAQAJh8LA&s=10'
    ]
})

print(rag_result)
# Out:
# 추천 와인: **Cocobon 2014 Red (California)**
#
# 이유: 구운 소고기와 잘 어울리는 grilled beef 향, 블랙베리와 블루베리 같은 진한 과실 풍미, 스모키하고 스파이시한 특징이 허브와 마늘로 양념한 소고기 패티의 savory하고 juicy한 맛, 은은한 charred 풍미와 잘 맞습니다. 풀바디 스타일이라 패티의 풍부한 맛도 충분히 받쳐 줍니다.
